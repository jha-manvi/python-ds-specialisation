# %%
from PIL import Image
from IPython.display import display
import numpy as np

# %%
im=Image.open('photo.jpeg')

# %%
display(im)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x589 at 0x7FE901076EE0>

# %%
array=np.array(im)

# %%
print(array.shape)
# Out:
# (589, 1280, 3)

# %%
array
# Out:
# array([[[ 17,  17,  17],
#         [ 13,  13,  13],
#         [ 16,  16,  16],
#         ...,
#         [ 83,  83,  83],
#         [ 62,  62,  62],
#         [ 91,  91,  91]],
#
#        [[ 30,  30,  30],
#         [ 24,  24,  24],
#         [ 25,  25,  25],
#         ...,
#         [ 87,  87,  87],
#         [ 74,  74,  74],
#         [100, 100, 100]],
#
#        [[ 24,  24,  24],
#         [ 18,  18,  18],
#         [ 17,  17,  17],
#         ...,
#         [ 95,  95,  95],
#         [ 85,  85,  85],
#         [ 99,  99,  99]],
#
#        ...,
#
#        [[ 72,  72,  72],
#         [ 68,  68,  68],
#         [ 67,  67,  67],
#         ...,
#         [ 73,  73,  73],
#         [ 71,  71,  71],
#         [ 66,  66,  66]],
#
#        [[ 83,  83,  83],
#         [ 78,  78,  78],
#         [ 74,  74,  74],
#         ...,
#         [ 75,  75,  75],
#         [ 76,  76,  76],
#         [ 73,  73,  73]],
#
#        [[ 89,  89,  89],
#         [ 84,  84,  84],
#         [ 79,  79,  79],
#         ...,
#         [ 91,  91,  91],
#         [ 95,  95,  95],
#         [ 94,  94,  94]]], dtype=uint8)

# %%
mask=np.full(array.shape,255)

# %%
mask
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]])

# %%
modified_array = array-mask

# %%
modified_array = modified_array * -1

# %%
modified_array = modified_array.astype(np.uint8)

# %%
display(Image.fromarray(modified_array))
# Out:
# <PIL.Image.Image image mode=RGB size=1280x589 at 0x7FE8C801CFA0>
