# %%
import pandas as pd

# %%
df=pd.read_csv('Admission_Predict.csv')

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df=df.rename(columns={'Chance of Admit ':'coa'})

# %%
df.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'coa'],
#       dtype='object')

# %%
mask=df['coa']>0.7

# %%
mask
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 395     True
# 396     True
# 397     True
# 398    False
# 399     True
# Name: coa, Length: 400, dtype: bool

# %%
df.where(mask).head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0         1.0      337.0        118.0                4.0  4.5   4.5  9.65
# 1         2.0      324.0        107.0                4.0  4.0   4.5  8.87
# 2         3.0      316.0        104.0                3.0  3.0   3.5  8.00
# 3         4.0      322.0        110.0                3.0  3.5   2.5  8.67
# 4         NaN        NaN          NaN                NaN  NaN   NaN   NaN
#
#    Research   coa
# 0       1.0  0.92
# 1       1.0  0.76
# 2       1.0  0.72
# 3       1.0  0.80
# 4       NaN   NaN

# %%
df.where(mask).dropna().head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0         1.0      337.0        118.0                4.0  4.5   4.5  9.65
# 1         2.0      324.0        107.0                4.0  4.0   4.5  8.87
# 2         3.0      316.0        104.0                3.0  3.0   3.5  8.00
# 3         4.0      322.0        110.0                3.0  3.5   2.5  8.67
# 5         6.0      330.0        115.0                5.0  4.5   3.0  9.34
#
#    Research   coa
# 0       1.0  0.92
# 1       1.0  0.76
# 2       1.0  0.72
# 3       1.0  0.80
# 5       1.0  0.90

# %%
df[df['coa']>0.7].head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 5           6        330          115                  5  4.5   3.0  9.34
#
#    Research   coa
# 0         1  0.92
# 1         1  0.76
# 2         1  0.72
# 3         1  0.80
# 5         1  0.90

# %%
df[(df['coa']>0.7)&(df['coa']<0.9)]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 6             7        321          109                  3  3.0   4.0  8.20
# 11           12        327          111                  4  4.0   4.5  9.00
# ..          ...        ...          ...                ...  ...   ...   ...
# 392         393        326          112                  4  4.0   3.5  9.12
# 393         394        317          104                  2  3.0   3.0  8.76
# 394         395        329          111                  4  4.5   4.0  9.23
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
#
#      Research   coa
# 1           1  0.76
# ...

# %%
df[df['coa'].gt(0.7)&df['coa'].lt(0.9)]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 6             7        321          109                  3  3.0   4.0  8.20
# 11           12        327          111                  4  4.0   4.5  9.00
# ..          ...        ...          ...                ...  ...   ...   ...
# 392         393        326          112                  4  4.0   3.5  9.12
# 393         394        317          104                  2  3.0   3.0  8.76
# 394         395        329          111                  4  4.5   4.0  9.23
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
#
#      Research   coa
# 1           1  0.76
# ...

# %% [markdown]
# Indexing DF

# %%
df['Serial No.']=df.index

# %%
df=df.set_index('coa')

# %%
df.head()
# Out:
#       Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# coa
# 0.92           0        337          118                  4  4.5   4.5  9.65
# 0.76           1        324          107                  4  4.0   4.5  8.87
# 0.72           2        316          104                  3  3.0   3.5  8.00
# 0.80           3        322          110                  3  3.5   2.5  8.67
# 0.65           4        314          103                  2  2.0   3.0  8.21
#
#       Research
# coa
# 0.92         1
# 0.76         1
# 0.72         1
# 0.80         1
# 0.65         0

# %%
df=df.reset_index()

# %%
df.head()
# Out:
#     coa  Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   \
# 0  0.92           0        337          118                  4  4.5   4.5
# 1  0.76           1        324          107                  4  4.0   4.5
# 2  0.72           2        316          104                  3  3.0   3.5
# 3  0.80           3        322          110                  3  3.5   2.5
# 4  0.65           4        314          103                  2  2.0   3.0
#
#    CGPA  Research
# 0  9.65         1
# 1  8.87         1
# 2  8.00         1
# 3  8.67         1
# 4  8.21         0

# %%
df=pd.read_csv('census.csv')

# %%
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
df['SUMLEV'].unique()
# Out:
# array([40, 50])

# %%
df=df[df['SUMLEV']==50]

# %%
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
# 5      50       3         6      1       9  Alabama   Blount County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
# 5          57322              57322            57373  ...          1.807375
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
cols_to_keep=['STNAME','CTYNAME','CENSUS2010POP']

# %%
df=df[cols_to_keep]

# %%
df.head()
# Out:
#     STNAME         CTYNAME  CENSUS2010POP
# 1  Alabama  Autauga County          54571
# 2  Alabama  Baldwin County         182265
# 3  Alabama  Barbour County          27457
# 4  Alabama     Bibb County          22915
# 5  Alabama   Blount County          57322

# %%
df=df.set_index(['STNAME','CTYNAME'])

# %%
df.head(20)
# Out:
#                           CENSUS2010POP
# STNAME  CTYNAME
# Alabama Autauga County            54571
#         Baldwin County           182265
#         Barbour County            27457
#         Bibb County               22915
#         Blount County             57322
#         Bullock County            10914
#         Butler County             20947
#         Calhoun County           118572
#         Chambers County           34215
#         Cherokee County           25989
#         Chilton County            43643
#         Choctaw County            13859
#         Clarke County             25833
#         Clay County               13932
#         Cleburne County           14972
#         Coffee County             49948
#         Colbert County            54428
#         Conecuh County            13228
#         Coosa County              11539
#         Covington County          37765

# %%
df.loc['Michigan','Wayne County']
# Out:
# CENSUS2010POP    1820584
# Name: (Michigan, Wayne County), dtype: int64

# %%
df.loc['Michigan']
# Out:
#                   CENSUS2010POP
# CTYNAME
# Alcona County             10942
# Alger County               9601
# Allegan County           111408
# Alpena County             29598
# Antrim County             23580
# ...                         ...
# Tuscola County            55729
# Van Buren County          76258
# Washtenaw County         344791
# Wayne County            1820584
# Wexford County            32735
#
# [83 rows x 1 columns]

# %%
df.loc[('Michigan','Antrim County')]
# Out:
# CENSUS2010POP    23580
# Name: (Michigan, Antrim County), dtype: int64

# %% [raw]
# Missing Values

# %%
df=pd.read_csv('class_grades.csv')

# %%
df.head()
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0       5       57.14     34.09    64.38     51.48  52.50
# 1       8       95.05    105.49    67.50     99.07  68.33
# 2       8       83.70     83.17      NaN     63.15  48.89
# 3       7         NaN       NaN    49.38    105.93  80.56
# 4       8       91.32     93.64    95.00    107.41  73.89

# %%
mask=df.isnull()

# %%
mask.head()
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0   False       False     False    False     False  False
# 1   False       False     False    False     False  False
# 2   False       False     False     True     False  False
# 3   False        True      True    False     False  False
# 4   False       False     False    False     False  False

# %%
df.dropna().head()
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0       5       57.14     34.09    64.38     51.48  52.50
# 1       8       95.05    105.49    67.50     99.07  68.33
# 4       8       91.32     93.64    95.00    107.41  73.89
# 5       7       95.00     92.58    93.12     97.78  68.06
# 6       8       95.05    102.99    56.25     99.07  50.00

# %%
#To fill all missing values with 0

# %%
df.fillna(0,inplace=True)

# %%
df.head()
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0       5       57.14     34.09    64.38     51.48  52.50
# 1       8       95.05    105.49    67.50     99.07  68.33
# 2       8       83.70     83.17     0.00     63.15  48.89
# 3       7        0.00      0.00    49.38    105.93  80.56
# 4       8       91.32     93.64    95.00    107.41  73.89

# %% [raw]
# Ffill and Bfill

# %%
df=pd.read_csv('log.csv')

# %%
df.head()
# Out:
#          time    user       video  playback position paused  volume
# 0  1469974424  cheryl  intro.html                  5  False    10.0
# 1  1469974454  cheryl  intro.html                  6    NaN     NaN
# 2  1469974544  cheryl  intro.html                  9    NaN     NaN
# 3  1469974574  cheryl  intro.html                 10    NaN     NaN
# 4  1469977514     bob  intro.html                  1    NaN     NaN

# %%
df=df.set_index('time')

# %%
df.head()
# Out:
#               user       video  playback position paused  volume
# time
# 1469974424  cheryl  intro.html                  5  False    10.0
# 1469974454  cheryl  intro.html                  6    NaN     NaN
# 1469974544  cheryl  intro.html                  9    NaN     NaN
# 1469974574  cheryl  intro.html                 10    NaN     NaN
# 1469977514     bob  intro.html                  1    NaN     NaN

# %%
df=df.sort_index()

# %%
df.head()
# Out:
#               user          video  playback position paused  volume
# time
# 1469974424  cheryl     intro.html                  5  False    10.0
# 1469974424     sue  advanced.html                 23  False    10.0
# 1469974454  cheryl     intro.html                  6    NaN     NaN
# 1469974454     sue  advanced.html                 24    NaN     NaN
# 1469974484  cheryl     intro.html                  7    NaN     NaN

# %%
df=df.reset_index()

# %%
df.head()
# Out:
#          time    user          video  playback position paused  volume
# 0  1469974424  cheryl     intro.html                  5  False    10.0
# 1  1469974424     sue  advanced.html                 23  False    10.0
# 2  1469974454  cheryl     intro.html                  6    NaN     NaN
# 3  1469974454     sue  advanced.html                 24    NaN     NaN
# 4  1469974484  cheryl     intro.html                  7    NaN     NaN

# %%
df=df.set_index(['time','user'])

# %%
df.head(20)
# Out:
#                            video  playback position paused  volume
# time       user
# 1469974424 cheryl     intro.html                  5  False    10.0
#            sue     advanced.html                 23  False    10.0
# 1469974454 cheryl     intro.html                  6    NaN     NaN
#            sue     advanced.html                 24    NaN     NaN
# 1469974484 cheryl     intro.html                  7    NaN     NaN
# 1469974514 cheryl     intro.html                  8    NaN     NaN
# 1469974524 sue     advanced.html                 25    NaN     NaN
# 1469974544 cheryl     intro.html                  9    NaN     NaN
# 1469974554 sue     advanced.html                 26    NaN     NaN
# 1469974574 cheryl     intro.html                 10    NaN     NaN
# 1469974604 cheryl     intro.html                 11    NaN     NaN
# 1469974624 sue     advanced.html                 27    NaN     NaN
# 1469974634 cheryl     intro.html                 12    NaN     NaN
# ...

# %%
df=df.fillna(method='ffill')

# %%
df.head()
# Out:
#                            video  playback position  paused  volume
# time       user
# 1469974424 cheryl     intro.html                  5   False    10.0
#            sue     advanced.html                 23   False    10.0
# 1469974454 cheryl     intro.html                  6   False    10.0
#            sue     advanced.html                 24   False    10.0
# 1469974484 cheryl     intro.html                  7   False    10.0

# %% [raw]
# Manipulating Dataframes

# %%
df=pd.read_csv('Presidents.csv')

# %%
df.head()
# Out:
#    #          President             Born      Age atstart of presidency  \
# 0  1  George Washington  Feb 22, 1732[a]  57 years, 67 daysApr 30, 1789
# 1  2         John Adams  Oct 30, 1735[a]  61 years, 125 daysMar 4, 1797
# 2  3   Thomas Jefferson  Apr 13, 1743[a]  57 years, 325 daysMar 4, 1801
# 3  4      James Madison  Mar 16, 1751[a]  57 years, 353 daysMar 4, 1809
# 4  5       James Monroe     Apr 28, 1758  58 years, 310 daysMar 4, 1817
#
#          Age atend of presidency Post-presidencytimespan          Died  \
# 0   65 years, 10 daysMar 4, 1797       2 years, 285 days  Dec 14, 1799
# 1  65 years, 125 daysMar 4, 1801      25 years, 122 days   Jul 4, 1826
# 2  65 years, 325 daysMar 4, 1809      17 years, 122 days   Jul 4, 1826
# 3  65 years, 353 daysMar 4, 1817      19 years, 116 days  Jun 28, 1836
# 4  66 years, 310 daysMar 4, 1825       6 years, 122 days   Jul 4, 1831
#
#                   Age
# 0  67 years, 295 days
# 1  90 years, 247 days
# 2   83 years, 82 days
# ...

# %%
df['First']=df['President']

# %%
df.head()
# Out:
#    #          President             Born      Age atstart of presidency  \
# 0  1  George Washington  Feb 22, 1732[a]  57 years, 67 daysApr 30, 1789
# 1  2         John Adams  Oct 30, 1735[a]  61 years, 125 daysMar 4, 1797
# 2  3   Thomas Jefferson  Apr 13, 1743[a]  57 years, 325 daysMar 4, 1801
# 3  4      James Madison  Mar 16, 1751[a]  57 years, 353 daysMar 4, 1809
# 4  5       James Monroe     Apr 28, 1758  58 years, 310 daysMar 4, 1817
#
#          Age atend of presidency Post-presidencytimespan          Died  \
# 0   65 years, 10 daysMar 4, 1797       2 years, 285 days  Dec 14, 1799
# 1  65 years, 125 daysMar 4, 1801      25 years, 122 days   Jul 4, 1826
# 2  65 years, 325 daysMar 4, 1809      17 years, 122 days   Jul 4, 1826
# 3  65 years, 353 daysMar 4, 1817      19 years, 116 days  Jun 28, 1836
# 4  66 years, 310 daysMar 4, 1825       6 years, 122 days   Jul 4, 1831
#
#                   Age              First
# 0  67 years, 295 days  George Washington
# ...

# %%
df['First']=df['First'].replace("[ ].*","",regex=True)

# %%
df.head()
# Out:
#    #          President             Born      Age atstart of presidency  \
# 0  1  George Washington  Feb 22, 1732[a]  57 years, 67 daysApr 30, 1789
# 1  2         John Adams  Oct 30, 1735[a]  61 years, 125 daysMar 4, 1797
# 2  3   Thomas Jefferson  Apr 13, 1743[a]  57 years, 325 daysMar 4, 1801
# 3  4      James Madison  Mar 16, 1751[a]  57 years, 353 daysMar 4, 1809
# 4  5       James Monroe     Apr 28, 1758  58 years, 310 daysMar 4, 1817
#
#          Age atend of presidency Post-presidencytimespan          Died  \
# 0   65 years, 10 daysMar 4, 1797       2 years, 285 days  Dec 14, 1799
# 1  65 years, 125 daysMar 4, 1801      25 years, 122 days   Jul 4, 1826
# 2  65 years, 325 daysMar 4, 1809      17 years, 122 days   Jul 4, 1826
# 3  65 years, 353 daysMar 4, 1817      19 years, 116 days  Jun 28, 1836
# 4  66 years, 310 daysMar 4, 1825       6 years, 122 days   Jul 4, 1831
#
#                   Age   First
# 0  67 years, 295 days  George
# 1  90 years, 247 days    John
# ...

# %%
del(df['First'])

# %%
df.head()
# Out:
#    #          President             Born      Age atstart of presidency  \
# 0  1  George Washington  Feb 22, 1732[a]  57 years, 67 daysApr 30, 1789
# 1  2         John Adams  Oct 30, 1735[a]  61 years, 125 daysMar 4, 1797
# 2  3   Thomas Jefferson  Apr 13, 1743[a]  57 years, 325 daysMar 4, 1801
# 3  4      James Madison  Mar 16, 1751[a]  57 years, 353 daysMar 4, 1809
# 4  5       James Monroe     Apr 28, 1758  58 years, 310 daysMar 4, 1817
#
#          Age atend of presidency Post-presidencytimespan          Died  \
# 0   65 years, 10 daysMar 4, 1797       2 years, 285 days  Dec 14, 1799
# 1  65 years, 125 daysMar 4, 1801      25 years, 122 days   Jul 4, 1826
# 2  65 years, 325 daysMar 4, 1809      17 years, 122 days   Jul 4, 1826
# 3  65 years, 353 daysMar 4, 1817      19 years, 116 days  Jun 28, 1836
# 4  66 years, 310 daysMar 4, 1825       6 years, 122 days   Jul 4, 1831
#
#                   Age
# 0  67 years, 295 days
# 1  90 years, 247 days
# 2   83 years, 82 days
# ...

# %%
def splitname(row):
    row['First']=row['President'].split(" ")[0]
    row['Last']=row['President'].split(" ")[-1]
    return row

# %%
df=df.apply(splitname,axis="columns")

# %%
df.head()
# Out:
#    #          President             Born      Age atstart of presidency  \
# 0  1  George Washington  Feb 22, 1732[a]  57 years, 67 daysApr 30, 1789
# 1  2         John Adams  Oct 30, 1735[a]  61 years, 125 daysMar 4, 1797
# 2  3   Thomas Jefferson  Apr 13, 1743[a]  57 years, 325 daysMar 4, 1801
# 3  4      James Madison  Mar 16, 1751[a]  57 years, 353 daysMar 4, 1809
# 4  5       James Monroe     Apr 28, 1758  58 years, 310 daysMar 4, 1817
#
#          Age atend of presidency Post-presidencytimespan          Died  \
# 0   65 years, 10 daysMar 4, 1797       2 years, 285 days  Dec 14, 1799
# 1  65 years, 125 daysMar 4, 1801      25 years, 122 days   Jul 4, 1826
# 2  65 years, 325 daysMar 4, 1809      17 years, 122 days   Jul 4, 1826
# 3  65 years, 353 daysMar 4, 1817      19 years, 116 days  Jun 28, 1836
# 4  66 years, 310 daysMar 4, 1825       6 years, 122 days   Jul 4, 1831
#
#                   Age   First        Last
# 0  67 years, 295 days  George  Washington
# ...

# %%
del(df['First'])
del(df['Last'])

# %%
pattern="(?P<First>^[\w]*)(?:.* )(?P<Last>[\w]*$)"

# %%
names=df["President"].str.extract(pattern).head()

# %%
names
# Out:
#     First        Last
# 0  George  Washington
# 1    John       Adams
# 2  Thomas   Jefferson
# 3   James     Madison
# 4   James      Monroe

# %%
df.T['George']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-206-c0487b197aaf> in <module>
# ----> 1 df.T['George']
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     352                 except ValueError as err:
#     353                     raise KeyError(key) from err
# --> 354             raise KeyError(key)
#     355         return super().get_loc(key, method=method, tolerance=tolerance)
#     356
#
# KeyError: 'George'

# %%
df["First"]=names["First"]

# %%
df["Last"]=names["Last"]

# %%
df.head()
# Out:
#    #          President             Born      Age atstart of presidency  \
# 0  1  George Washington  Feb 22, 1732[a]  57 years, 67 daysApr 30, 1789
# 1  2         John Adams  Oct 30, 1735[a]  61 years, 125 daysMar 4, 1797
# 2  3   Thomas Jefferson  Apr 13, 1743[a]  57 years, 325 daysMar 4, 1801
# 3  4      James Madison  Mar 16, 1751[a]  57 years, 353 daysMar 4, 1809
# 4  5       James Monroe     Apr 28, 1758  58 years, 310 daysMar 4, 1817
#
#          Age atend of presidency Post-presidencytimespan          Died  \
# 0   65 years, 10 daysMar 4, 1797       2 years, 285 days  Dec 14, 1799
# 1  65 years, 125 daysMar 4, 1801      25 years, 122 days   Jul 4, 1826
# 2  65 years, 325 daysMar 4, 1809      17 years, 122 days   Jul 4, 1826
# 3  65 years, 353 daysMar 4, 1817      19 years, 116 days  Jun 28, 1836
# 4  66 years, 310 daysMar 4, 1825       6 years, 122 days   Jul 4, 1831
#
#                   Age   First        Last
# 0  67 years, 295 days  George  Washington
# ...

# %%
df["Born"]=df["Born"].str.extract("([\w]{3} [\w]{1,2}, [\w]{4})")

# %%
df["Born"].head()
# Out:
# 0    Feb 22, 1732
# 1    Oct 30, 1735
# 2    Apr 13, 1743
# 3    Mar 16, 1751
# 4    Apr 28, 1758
# Name: Born, dtype: object

# %%
df['Born']=pd.to_datetime(df["Born"])

# %%
df["Born"].head()
# Out:
# 0   1732-02-22
# 1   1735-10-30
# 2   1743-04-13
# 3   1751-03-16
# 4   1758-04-28
# Name: Born, dtype: datetime64[ns]

# %%
df1=pd.read_csv("Admission_Predict.csv")

# %%
df1.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df1.where(df1['TOEFL Score']>105)
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1.0      337.0        118.0                4.0  4.5   4.5  9.65
# 1           2.0      324.0        107.0                4.0  4.0   4.5  8.87
# 2           NaN        NaN          NaN                NaN  NaN   NaN   NaN
# 3           4.0      322.0        110.0                3.0  3.5   2.5  8.67
# 4           NaN        NaN          NaN                NaN  NaN   NaN   NaN
# ..          ...        ...          ...                ...  ...   ...   ...
# 395       396.0      324.0        110.0                3.0  3.5   3.5  9.04
# 396       397.0      325.0        107.0                3.0  3.0   3.5  9.11
# 397       398.0      330.0        116.0                4.0  5.0   4.5  9.45
# 398         NaN        NaN          NaN                NaN  NaN   NaN   NaN
# 399       400.0      333.0        117.0                4.0  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %%
df=df1.rename(columns={'TOEFL Score':'toefl score'})

# %%
df.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'toefl score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
df[(df['toefl score'] > 105) & (df['toefl score'] < 115)]
# Out:
#      Serial No.  GRE Score  toefl score  University Rating  SOP  LOR   CGPA  \
# 1             2        324          107                  4  4.0   4.5  8.87
# 3             4        322          110                  3  3.5   2.5  8.67
# 6             7        321          109                  3  3.0   4.0  8.20
# 9            10        323          108                  3  3.5   3.0  8.60
# 10           11        325          106                  3  3.5   4.0  8.40
# ..          ...        ...          ...                ...  ...   ...   ...
# 391         392        318          106                  3  2.0   3.0  8.65
# 392         393        326          112                  4  4.0   3.5  9.12
# 394         395        329          111                  4  4.5   4.0  9.23
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
#
#      Research  Chance of Admit
# ...

# %%
df[df['toefl score'].gt(105) & df['toefl score'].lt(115)]
# Out:
#      Serial No.  GRE Score  toefl score  University Rating  SOP  LOR   CGPA  \
# 1             2        324          107                  4  4.0   4.5  8.87
# 3             4        322          110                  3  3.5   2.5  8.67
# 6             7        321          109                  3  3.0   4.0  8.20
# 9            10        323          108                  3  3.5   3.0  8.60
# 10           11        325          106                  3  3.5   4.0  8.40
# ..          ...        ...          ...                ...  ...   ...   ...
# 391         392        318          106                  3  2.0   3.0  8.65
# 392         393        326          112                  4  4.0   3.5  9.12
# 394         395        329          111                  4  4.5   4.0  9.23
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
#
#      Research  Chance of Admit
# ...

# %%
s1 = pd.Series({1: 'Alice', 2: 'Jack', 3: 'Molly'})
s2 = pd.Series({'Alice': 1, 'Jack': 2, 'Molly': 3})

# %%
s2[1]
# Out:
# 2

# %%
s2.loc[]
# Out:
# 2
